# %% [markdown]
# # Final Project Guideline
#
# ## Goals
# Peserta diminta untuk membuat **aplikasi Python interaktif berbasis Streamlit** dengan **minimal satu fitur AI** atau **fungsionalitas interaktif** lainnya. Proyek ini bertujuan untuk menunjukkan penerapan semua materi yang telah dipelajari selama program.
#
#
#
# ## Kriteria Project
# - Menggunakan **Python** sebagai bahasa utama.
# - Menggunakan **Streamlit** sebagai UI aplikasi.
# - Minimal **1 fitur interaktif** (input form, tombol, chatbot, dll).
# - Wajib menggunakan minimal **1 library eksternal** selain `streamlit`.
# - Disarankan menerapkan konsep-konsep Python yang telah dipelajari, seperti: OOP, Data Structures, Looping, etc.
# - **Deploy** aplikasi ke platform seperti:
#   - [Streamlit Cloud](https://share.streamlit.io/)
#   - [HuggingFace Space](https://huggingface.co/spaces)
# - Sertakan **dokumentasi proyek** (README.md atau PDF).
#
#
#
# ## Struktur File Submit
#
# Submit dalam bentuk **Google Drive atau GitHub Repo** dan share link-nya melalui form yang akan disediakan.
#
#
#
#
# ## Dokumentasi Wajib Memuat
# 1. Judul Project
# 2. Deskripsi Singkat (latar belakang masalah & tujuan)
# 3. Fitur-Fitur Utama
# 4. Cara Menjalankan di Lokal
# 5. Preview Aplikasi (Screenshot / Demo)
# 6. Link Deploy Aplikasi
#
#
#
# ## Rubrik Penilaian Final Project
#
# | No | Aspek | Deskripsi | Skor Maks | Kriteria Penilaian |
# |----|-------|-----------|-----------|---------------------|
# | 1 | **Penerapan Konsep Python** | Penggunaan `class`, `object`, loop, list, dict, dll. | 20 | - **18–20**: Semua konsep diterapkan sangat baik dan efektif  <br>- **13–17**: Umumnya diterapkan, tapi ada bagian kurang optimal <br>- **<13**: Minim penggunaan konsep Python |
# | 2 | **Fungsionalitas & Fitur Interaktif** | Aplikasi berjalan baik & interaktif | 30 | - **27–30**: Fitur berjalan lancar <br>- **20–26**: Beberapa fitur belum responsif <br>- **<20**: Aplikasi tidak berjalan sesuai harapan |
# | 3 | **Pemanfaatan Library** | Penggunaan pustaka modern & relevan | 15 | - **13–15**: Digunakan dengan optimal <br>- **10–12**: Cukup tepat, masih bisa dioptimalkan <br>- **<10**: Kurang sesuai atau tidak digunakan |
# | 4 | **Dokumentasi & Presentasi** | README atau PDF lengkap & informatif | 10 | - **9–10**: Dokumentasi lengkap dan menarik <br>- **6–8**: Ada tapi kurang detail <br>- **<6**: Minim atau tidak ada dokumentasi |
# | 5 | **Pengujian & Debugging** | Bebas bug besar & diuji | 10 | - **9–10**: Aplikasi diuji dengan baik <br>- **7–8**: Ada bug kecil <br>- **<7**: Tidak dilakukan testing |
# | 6 | **Deployment** | Berhasil online tanpa masalah besar | 10 | - **9–10**: Bisa diakses publik tanpa error <br>- **6–8**: Ada error kecil <br>- **<6**: Tidak berhasil deploy |
# | 7 | **Kreativitas & Inovasi** | Fitur unik, UI menarik, pendekatan out-of-the-box | 5 | - **5**: Sangat kreatif & inovatif <br>- **3–4**: Kreatif tapi biasa <br>- **<3**: Kurang kreatif, hanya mengikuti dasar |
#
#
#
# ## Cara Submit
# 1. Upload semua file ke Google Drive atau GitHub Repo.
# 2. Pastikan akses folder/repo **public (viewable)**.
# 3. Isi **Form Submit Final Project** (akan dibagikan oleh learning buddy):
#    - Nama Kelompok
#    - Anggota Kelompok
#    - Judul Project
#    - Link Google Drive / GitHub Repo
#    - Link Deploy Aplikasi
#
#
#
# ## 💡 Contoh Ide Final Project
# - Chatbot edukasi berbasis Streamlit
# - Aplikasi prediksi harga rumah sederhana
# - Dashboard visualisasi data (CSV input)
# - Kuisioner AI dengan feedback otomatis
# - Rekomendasi film berbasis genre & rating
