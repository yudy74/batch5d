# %% [markdown]
# # Fun Project #1 - Mini Quiz App dengan Streamlit
#
# ### **Project Description**
# Peserta akan membuat **Mini Quiz App** menggunakan **Streamlit** yang membantu pengguna mengetahui profesi yang cocok berdasarkan pilihan-pilihan mereka. Kuis ini akan menampilkan beberapa pertanyaan dan berdasarkan jawaban, pengguna akan diberi hasil yang mengarah pada salah satu profesi, misalnya: Programmer, Designer, atau Data Scientist.
#
# ### **Key Features**
# - **Multiple Choice Questions (Radio Buttons)**: Menampilkan serangkaian pertanyaan dengan pilihan jawaban menggunakan **radio buttons**.
# - **Skoring Berdasarkan Jawaban**: Menghitung skor untuk masing-masing kategori (Programmer, Designer, Data Scientist) berdasarkan jawaban yang dipilih pengguna.
# - **UI yang Menarik**: Menambahkan gambar dan pesan untuk hasil kuis yang menarik.
# - **Tombol untuk Melihat Hasil**: Pengguna dapat menekan tombol untuk melihat hasil berdasarkan jawaban yang mereka pilih.
#
# ### **Day 1 - Core Features**
# 1. **Setup Streamlit** dan membuat tampilan dasar aplikasi.
# 2. **Membuat Pertanyaan**: Menambahkan beberapa pertanyaan dengan pilihan jawaban menggunakan **radio buttons**.
# 3. **Skoring dan Hasil**: Menambahkan logika untuk menghitung skor berdasarkan pilihan jawaban dan menampilkan hasil yang sesuai.
#
# ### **Day 2 - Finishing & Showcase**
# 1. **Menyempurnakan Antarmuka**: Menambah elemen visual seperti **gambar** atau **icon** untuk membuat aplikasi lebih menarik.
# 2. **Pengujian & Penyempurnaan**: Pastikan aplikasi berjalan lancar dan hasil kuis sesuai dengan jawaban.
#
# ---
#
#
#
# # Panduan Pengumpulan Proyek Fun Project 1
#
# ## 1. **Persiapkan Proyek**
# - Pastikan struktur folder kamu rapi seperti berikut ini:
#      ```
#      fun_project_1_REAID
#          - app.py
#          - README.md (opsional)
#          - assets (opsional) folder gambar/icon jika ada
#      ```
#
# ## 2. **Pastikan Aplikasi Bisa Jalan**
# Sebelum submit, pastikan aplikasimu bisa dibuka dengan:
# ```
# streamlit run app.py
# ```
#
# ## 3. **Upload Project**
# Kamu boleh memilih salah satu dari dua opsi berikut:
# - **Opsi A: Upload ke Google Drive**
# 	1.	Upload folder **fun_project_1_REAID**/ ke akun Google Drive kamu.
# 	2.	Klik kanan folder tersebut → pilih “Get link” / “Dapatkan tautan”.
# 	3.	Ubah aksesnya menjadi “Siapa saja yang memiliki link dapat melihat” (Anyone with the link can view).
#
# - **Opsi B: Upload ke GitHub**
# 	1.	Buat repositori baru di GitHub.
# 	2.	Upload semua file dan folder dari proyekmu ke repositori tersebut.
# 	3.	Pastikan file app.py ada di root repositori dan dapat dilihat publik.
#
# ## 4. **Submit Link ke LMS**
# 	1.	Buka LMS dan temukan Fun Project#1 - Submission.
# 	2.	Lampirkan URL Google Drive atau link GitHub kamu pada kolom yang disediakan dan klik simpan.
#
# ## 5. **Deadline**
# Pastikan untuk mengirimkan file ZIP kamu melalui Google Form sebelum **16 Juni 2025 (23:59 WIB)**.
#
# ## 6. **Rubric Penilaian**
#
# | No  | Aspek Penilaian             | Definisi                                                                 | Skor Maks | Kriteria Penilaian                                                                                                 |
# |-----|-----------------------------|--------------------------------------------------------------------------|-----------|---------------------------------------------------------------------------------------------------------------------|
# | 1   | Fungsionalitas              | Program berjalan sesuai instruksi, input-output sesuai ekspektasi, dan tidak error. | 40        | - 36–40: Berjalan sempurna, sesuai instruksi, hasil akurat <br> - 30–35: Ada minor bug/kekurangan kecil <br> - <30: Gagal menjalankan fungsi utama atau error besar |
# | 2   | Kode Bersih & Terstruktur   | Kode mudah dibaca, nama variabel jelas, indentasi rapi, tidak ada baris sia-sia. | 20        | - 18–20: Penamaan & struktur sangat rapi <br> - 15–17: Cukup rapi, ada sedikit kekurangan <br> - <15: Banyak kode tidak rapi/tidak konsisten |
# | 3   | Kreativitas / Modifikasi    | Ada fitur tambahan, gaya personal, atau twist di dalam proyek.             | 20        | - 18–20: Fitur tambahan menarik & relevan <br> - 15–17: Ada modifikasi minor <br> - <15: Tidak ada modifikasi sama sekali |
# | 4   | Dokumentasi / Penjelasan    | Dokumentasi berupa screenshot/preview aplikasi dan instruksi cara penggunaan. | 10        | - 9–10: Ada screenshot, preview aplikasi, dan langkah-langkah penggunaan yang jelas <br> - 7–8: Ada beberapa penjelasan, tapi tidak lengkap <br> - <7: Tidak ada dokumentasi visual atau penjelasan langkah-langkah |
# | 5   | Error Handling              | Program tetap stabil saat input salah atau tidak sesuai.                   | 10        | - 9–10: Tangani error dengan baik <br> - 7–8: Ada penanganan dasar <br> - <7: Program crash saat input tidak valid |
# |     | **Total**                   |                                                                          | **100**   |                                                                                                                     |
#
# **Selamat Mengerjakan dan Semoga Berhasil! 🚀**
#
# ## 7. **Referensi Project**
# https://demo-fun-project-1.streamlit.app/
